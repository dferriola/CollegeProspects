# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
plt.style.use('seaborn-notebook')
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df=pd.read_csv('degrees.csv')

# %%
df1=pd.read_csv('salariesbycollege.csv')

# %%
df2=pd.read_csv('salariesbyregion.csv')

# %%
df[:10]
# Out:
#      Undergraduate Major Starting Median Salary Mid-Career Median Salary  \
# 0             Accounting             $46,000.00               $77,100.00
# 1  Aerospace Engineering             $57,700.00              $101,000.00
# 2            Agriculture             $42,600.00               $71,900.00
# 3           Anthropology             $36,800.00               $61,500.00
# 4           Architecture             $41,600.00               $76,800.00
# 5            Art History             $35,800.00               $64,900.00
# 6                Biology             $38,800.00               $64,800.00
# 7    Business Management             $43,000.00               $72,100.00
# 8   Chemical Engineering             $63,200.00              $107,000.00
# 9              Chemistry             $42,600.00               $79,900.00
#
#    Percent change from Starting to Mid-Career Salary  \
# 0                                               67.6
# 1                                               75.0
# ...

# %%
df[df.columns[1:]].replace('[\$,]', '', regex=True).astype(float)##convert to float and remove the dollar signs
# Out:
#     Starting Median Salary  Mid-Career Median Salary  \
# 0                  46000.0                   77100.0
# 1                  57700.0                  101000.0
# 2                  42600.0                   71900.0
# 3                  36800.0                   61500.0
# 4                  41600.0                   76800.0
# 5                  35800.0                   64900.0
# 6                  38800.0                   64800.0
# 7                  43000.0                   72100.0
# 8                  63200.0                  107000.0
# 9                  42600.0                   79900.0
# 10                 53900.0                   90500.0
# 11                 38100.0                   70000.0
# 12                 61400.0                  105000.0
# 13                 55900.0                   95500.0
# 14                 53700.0                   88900.0
# 15                 35000.0                   56300.0
# 16                 35900.0                   56900.0
# ...

# %%
df[:10]
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
# 5            Art History                 35800.0                   64900.0
# 6                Biology                 38800.0                   64800.0
# 7    Business Management                 43000.0                   72100.0
# 8   Chemical Engineering                 63200.0                  107000.0
# 9              Chemistry                 42600.0                   79900.0
#
#    Percent change from Starting to Mid-Career Salary  \
# 0                                               67.6
# ...

# %%
df['Percent change from Starting to Mid-Career Salary'].mean()
# Out:
# 69.27399999999999

# %%
df.describe()
# Out:
#        Starting Median Salary  Mid-Career Median Salary  \
# count               50.000000                  50.00000
# mean             44310.000000               74786.00000
# std               9360.866217               16088.40386
# min              34000.000000               52000.00000
# 25%              37050.000000               60825.00000
# 50%              40850.000000               72000.00000
# 75%              49875.000000               88750.00000
# max              74300.000000              107000.00000
#
#        Percent change from Starting to Mid-Career Salary  \
# count                                          50.000000
# mean                                           69.274000
# std                                            17.909908
# min                                            23.400000
# 25%                                            59.125000
# 50%                                            67.800000
# ...

# %%
df.sort_values(by ='Mid-Career Median Salary', ascending = False, inplace=True)

# %%
dfd=df[:10]

# %%
df.sort_values(by ='Mid-Career Median Salary', ascending = True, inplace=True)

# %%
df[:10] ##descending least amount mid-career salary
# Out:
#    level_0  index    Undergraduate Major  Starting Median Salary  \
# 0        0     47               Religion                 34100.0
# 1        1     18              Education                 34900.0
# 2        2     49                Spanish                 34000.0
# 3        3     32        Interior Design                 36100.0
# 4        4     39                  Music                 35900.0
# 5        5     41              Nutrition                 39900.0
# 6        6     15       Criminal Justice                 35000.0
# 7        7     16                  Drama                 35900.0
# 8        8     29  Hospitality & Tourism                 37800.0
# 9        9     48              Sociology                 36500.0
#
#    Mid-Career Median Salary  \
# 0                   52000.0
# 1                   52000.0
# 2                   53100.0
# 3                   53200.0
# 4                   55000.0
# 5                   55300.0
# 6                   56300.0
# ...

# %%
df1.head()
df2.head()
# Out:
#                                 School Name      Region  \
# 0                       Stanford University  California
# 1  California Institute of Technology (CIT)  California
# 2                       Harvey Mudd College  California
# 3        University of California, Berkeley  California
# 4                        Occidental College  California
#
#   Starting Median Salary Mid-Career Median Salary  \
# 0             $70,400.00              $129,000.00
# 1             $75,500.00              $123,000.00
# 2             $71,800.00              $122,000.00
# 3             $59,900.00              $112,000.00
# 4             $51,900.00              $105,000.00
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                        $68,400.00                        $93,100.00
# 1                               NaN                       $104,000.00
# 2                               NaN                        $96,000.00
# ...

# %%
dfd.plot (x='Undergraduate Major', y='Starting Median Salary', kind='barh')

# %%
df.plot(x='Starting Median Salary', y='Mid-Career Median Salary', 
        kind='scatter')
plt.title('Starting and Mid-Career Salary')

# %%
df.plot(y='Starting Median Salary', kind='box')

# %%
df.plot(y='Mid-Career Median Salary', kind='box')

# %%
df.plot(y='Mid-Career Median Salary', kind='hist')
plt.title('Mid Career Median Salary')

# %%
df.plot(y='Starting Median Salary', kind='hist', 
        normed=True )
plt.title('Starting Median Salary')

# %%
df.describe()
# Out:
#         level_0     index  Starting Median Salary  Mid-Career Median Salary  \
# count  50.00000  50.00000               50.000000                  50.00000
# mean   24.50000  24.50000            44310.000000               74786.00000
# std    14.57738  14.57738             9360.866217               16088.40386
# min     0.00000   0.00000            34000.000000               52000.00000
# 25%    12.25000  12.25000            37050.000000               60825.00000
# 50%    24.50000  24.50000            40850.000000               72000.00000
# 75%    36.75000  36.75000            49875.000000               88750.00000
# max    49.00000  49.00000            74300.000000              107000.00000
#
#        Percent change from Starting to Mid-Career Salary  \
# count                                          50.000000
# mean                                           69.274000
# std                                            17.909908
# ...

# %%
df.mean
# Out:
# <bound method DataFrame.mean of     level_0  index                   Undergraduate Major  \
# 0         0     47                              Religion
# 1         1     18                             Education
# 2         2     49                               Spanish
# 3         3     32                       Interior Design
# 4         4     39                                 Music
# 5         5     41                             Nutrition
# 6         6     15                      Criminal Justice
# 7         7     16                                 Drama
# 8         8     29                 Hospitality & Tourism
# 9         9     48                             Sociology
# 10       10     26                        Graphic Design
# 11       11     46                            Psychology
# 12       12     27            Health Care Administration
# 13       13      3                          Anthropology
# 14       14     23                              Forestry
# ...

# %%
df.std()
# Out:
# level_0                                                 14.577380
# index                                                   14.577380
# Starting Median Salary                                9360.866217
# Mid-Career Median Salary                             16088.403860
# Percent change from Starting to Mid-Career Salary       17.909908
# Mid-Career 10th Percentile Salary                    12000.779567
# Mid-Career 25th Percentile Salary                    13936.951911
# Mid-Career 75th Percentile Salary                    20636.789914
# dtype: float64

# %%
df.quantile()
# Out:
# level_0                                                 24.5
# index                                                   24.5
# Starting Median Salary                               40850.0
# Mid-Career Median Salary                             72000.0
# Percent change from Starting to Mid-Career Salary       67.8
# Mid-Career 10th Percentile Salary                    39400.0
# Mid-Career 25th Percentile Salary                    52450.0
# Mid-Career 75th Percentile Salary                    99400.0
# Name: 0.5, dtype: float64

# %%
df.min()
# Out:
# level_0                                                        0
# index                                                          0
# Undergraduate Major                                   Accounting
# Starting Median Salary                                     34000
# Mid-Career Median Salary                                   52000
# Percent change from Starting to Mid-Career Salary           23.4
# Mid-Career 10th Percentile Salary                          26700
# Mid-Career 25th Percentile Salary                          36500
# Mid-Career 75th Percentile Salary                          70500
# Mid-Career 90th Percentile Salary                    $101,000.00
# dtype: object

# %%
df.max()
# Out:
# level_0                                                      49
# index                                                        49
# Undergraduate Major                                     Spanish
# Starting Median Salary                                    74300
# Mid-Career Median Salary                                 107000
# Percent change from Starting to Mid-Career Salary         103.5
# Mid-Career 10th Percentile Salary                         71900
# Mid-Career 25th Percentile Salary                         87300
# Mid-Career 75th Percentile Salary                        145000
# Mid-Career 90th Percentile Salary                    $99,200.00
# dtype: object

# %%
df.plot(kind=box)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-4449e2020537> in <module>()
# ----> 1 df.plot(kind=box)
#
# /Users/dmf/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3771                           fontsize=fontsize, colormap=colormap, table=table,
#    3772                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3773                           sort_columns=sort_columns, **kwds)
#    3774     __call__.__doc__ = plot_frame.__doc__
#    3775
#
# ...
